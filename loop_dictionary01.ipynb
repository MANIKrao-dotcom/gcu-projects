# %%
students = {
    "manik": {
        "math": 85,
        "python": 92
    },
    "taufiq": {
        "math": 78,
        "python": 88
    }
}
for student, subjects in students.items():
    print(student)
    print(subjects)
# Out:
# manik
# {'math': 85, 'python': 92}
# taufiq
# {'math': 78, 'python': 88}
