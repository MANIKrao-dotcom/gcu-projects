# %%
from functools import reduce

data = [
    [1, 2],
    [3, 4],
    [5, 6]
]

result = reduce(
    lambda a, b: a * b,
    map(
        lambda x: reduce(lambda p, q: p * q, x),
        data
    )
)

print(result)
# Out:
# 720
