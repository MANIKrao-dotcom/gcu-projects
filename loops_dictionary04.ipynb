# %%
students = {
    "manik": {
        "math": 85,
        "python": 92
    },
    "taufiq": {
        "math": 78,
        "python": 88
    }
}
for outer_key, inner_dictionary in students.items():

    for inner_key, value in inner_dictionary.items():
        print(f"{outer_key}: {inner_key} = {value}")
# Out:
# manik: math = 85
# manik: python = 92
# taufiq: math = 78
# taufiq: python = 88
