# %%
marks = {
    "Manik": 85,
    "Taufiq": 72,
    "Abhi": 91,
    "Surya": 64
}

highest_marks = 0
topper = ""

for name, score in marks.items():
    if score > highest_marks:
        highest_marks = score
        topper = name

print("Topper :", topper)
print("Marks :", highest_marks)
# Out:
# Topper : Abhi
# Marks : 91
