# %%
countries = (
    ("India", ("Karnataka", "Kerala", "Tamil Nadu")),
    ("USA", ("Texas", "California", "Florida")),
    ("Japan", ("Tokyo", "Osaka", "Kyoto"))
)

for country in countries:
    print("Country:", country[0])

    for state in country[1]:
        print("State:", state)

    print()
# Out:
# Country: India
# State: Karnataka
# State: Kerala
# State: Tamil Nadu
#
# Country: USA
# State: Texas
# State: California
# State: Florida
#
# Country: Japan
# State: Tokyo
# State: Osaka
# State: Kyoto
