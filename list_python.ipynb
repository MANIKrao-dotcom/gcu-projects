# %%
#list.sort():-it updates  the list into accending order
#list.sort():-it changes or update in list but it dosent give output(error)
#so to print updated list give print(list)

#list.reverse():-it updates the list to reverse from the given list
#list.reverse():-it changes or update in list but it doseent give output(error)
#so to print updated list give print(list)

#list.append(8):-it update the list to include ,add the given number into the list
#it changes or update in list but it doseent give output(error)
##so to print updated list give print(list)

#list.insert(3,8):-it updates the list where it insert number 8 at 3index
#it changes or update in list but it doseent give output(error)
##so to print updated list give print(list)

#list.remove(21):- it removes the given number from the list
#it changes or update in list but it doseent give output(error)
##so to print updated list give print(list)

#list.pop(2):-it remove the number from iindex 2 and returns the value
#it changes or update in list but it doseent give output(error)
##so to print updated list give print(list)

# %%
list = [10, 20, 30, 40, 50, 60]
print("list")
print(list)
# Out:
# list
# [10, 20, 30, 40, 50, 60]

# %%
list = ["kiran" ,99.90 ,"bihar"]
print(list)
# Out:
# ['kiran', 99.9, 'bihar']

# %%
#list is a built -in data type that stores set of values
#it can store element of different type(integer, float, strinng, etc)
#it also starts with 0 like strings
marks = [10, 20, 30, 40, 50, 60, 70]
print(marks)
print(len(marks))
print(marks[2])
print(marks[0])
# Out:
# [10, 20, 30, 40, 50, 60, 70]
# 7
# 30
# 10

# %%
#strings = immutiable(cannot be changed)
#list = muitable(can be changed)
student = ["kiran", 77.89, 16,"delhi" ]
print(student[0])
student[0] = "arjun"#muitable
print(student[0])
print(student[3])
print(student[2])
print(student[4])#gives error
# Out:
# kiran
# arjun
# delhi
# 16

# %%
marks = [35, 40, 45, 50, 55, 60, 65, 70]#here indix starts from 0
print(marks[2:7])
print(marks[ :5])#if first ration is not given then it consider the first obv in list
print(marks[0:5])#same as above
print(marks[0:])#last ratio is not given then it is considered the end of strings
print(marks[0:len(marks)])#same as above
print(marks[-3:-1])
# Out:
# [45, 50, 55, 60, 65]
# [35, 40, 45, 50, 55]
# [35, 40, 45, 50, 55]
# [35, 40, 45, 50, 55, 60, 65, 70]
# [35, 40, 45, 50, 55, 60, 65, 70]
# [60, 65]

# %%
#adds one element at the end
list = [2, 1, 3, 4]
list.append(4)
print(list)

num = [2, 1, 3, ]
num.append(4)
print(num)
# Out:
# [2, 1, 3, 4, 4]
# [2, 1, 3, 4]

# %%
#sort = arrange in acending or decending order
list = [3, 1, 2, 6, 4, 5,]
list.sort()
print(list)

list.sort(reverse = True)#true the first letter should capital"T"
print(list)
# Out:
# [1, 2, 3, 4, 5, 6]
# [6, 5, 4, 3, 2, 1]

# %%
list = [2, 1, 3,]
print(list.append(4))#return none bcz it nodifies the list in place does not return the updated list
print(list)  #for updated 

list = [2, 1, 3, 4]
new_list = list + [4]
print(new_list)

a = [2, 1, 3, 5]
a.append(0)
print(a)
# Out:
# None
# [2, 1, 3, 4]
# [2, 1, 3, 4, 4]
# [2, 1, 3, 5, 0]

# %%
list = [2, 1, 3, 4,]
print(list.append(7))
(list.sort())#it modifies the original list(now it is modified but not show unless said)
print(list)#to run the modified list (inthis line we say to show the modification)


#sort() → returns None
#So you're printing None, not the list
# Out:
# None
# [1, 2, 3, 4, 7]

# %%
fruits = ["orange", "banana", "apple"]
print(fruits.sort())#return none becose the modification is done in original list but not shown untill asked
print(fruits)#this line asked the modified data

fruits.sort(reverse = True)
print(fruits)

print(type(fruits))
# Out:
# None
# ['apple', 'banana', 'orange']
# ['orange', 'banana', 'apple']
# <class 'list'>

# %%
age = [67, 20, 34, 46, 11, 0, 4, 2, 5, 3]
print(age.sort())#none
print(age)#sorted

print(age.sort(reverse = True))#none
print(age)
# Out:
# None
# [0, 2, 3, 4, 5, 11, 20, 34, 46, 67]
# None
# [67, 46, 34, 20, 11, 5, 4, 3, 2, 0]

# %%
#insert adds new value between index
num = [3, 1, 5, 2, 4, 7]
print(num.insert(1,5))#none
print(num)
# Out:
# None
# [3, 5, 1, 5, 2, 4, 7]

# %%
#removefirst occurrence of element
age = [34, 45, 12, 67, 11, 32, 7]
print(age.remove(12))#none
print(age)

age = [34, 45, 12, 67, 11, 32, 7]
print(age.pop(3))#third index popupp and displaces it but it will not run when you print age seperately it will run
print(age)
# Out:
# None
# [34, 45, 67, 11, 32, 7]
# 67
# [34, 45, 12, 11, 32, 7]

# %%
movies = []
mov1 = input("enter 1st movie:")
mov2 = input("enter 2nd movie:")
mov3 = input("enter 3rd movie:")

(movies.append(mov3))
(movies.append(mov1))#remember append dosent print anything so print movies sepperatly to acces movies
(movies.append(mov2))

print(movies)
# Out:
# ['d', 'a', 's']

# %%
#check the list containing aplindrome of element.(hint=copy(methord))
list1 = [1,2,1]
list2 = [1,2,3]

copy_list1 = list.copy()
copy_list1.reverse()

if (copy_list1 == list1):
    print("plindrome")
else:
    print("not a plindrome")
# Out:
# not a palindrome

# %%
'''not work with strimg same as the numbers in the string so take a list which splits string into chracter '''
word1 =list("manik")
word2 =list("kinam")
copy_word = word1.copy()
copy_word.reverse()
if copy_word == word2:
    print("yes it is a palindrome")
else:
        print("not a palindrome")
# Out:
# 'not work with strimg same as the numbers in the string '

# %%
list =[]
list.append("a")
list.append("b")
list.append("c")
list.append("e")
print(list)
list.insert(3,"i")
print(list)
# Out:
# ['a', 'b', 'c', 'e']
# ['a', 'b', 'c', 'i', 'e']

# %%
for i in range(1,10):
    for j in range(1,11):
        print(f"{i} * {j} == {i*j}")
        print()
# Out:
# 1 * 1 == 1
#
# 1 * 2 == 2
#
# 1 * 3 == 3
#
# 1 * 4 == 4
#
# 1 * 5 == 5
#
# 1 * 6 == 6
#
# 1 * 7 == 7
#
# 1 * 8 == 8
#
# 1 * 9 == 9
#
# 1 * 10 == 10
#
# 2 * 1 == 2
#
# 2 * 2 == 4
#
# 2 * 3 == 6
#
# 2 * 4 == 8
#
# 2 * 5 == 10
#
# 2 * 6 == 12
#
# 2 * 7 == 14
#
# 2 * 8 == 16
#
# 2 * 9 == 18
#
# 2 * 10 == 20
#
# 3 * 1 == 3
#
# 3 * 2 == 6
#
# 3 * 3 == 9
#
# 3 * 4 == 12
#
# 3 * 5 == 15
#
# 3 * 6 == 18
#
# 3 * 7 == 21
#
# 3 * 8 == 24
#
# 3 * 9 == 27
#
# 3 * 10 == 30
#
# 4 * 1 == 4
#
# 4 * 2 == 8
#
# 4 * 3 == 12
#
# 4 * 4 == 16
#
# 4 * 5 == 20
#
# 4 * 6 == 24
#
# 4 * 7 == 28
#
# 4 * 8 == 32
#
# 4 * 9 == 36
#
# 4 * 10 == 40
#
# 5 * 1 == 5
#
# 5 * 2 == 10
#
# 5 * 3 == 15
#
# 5 * 4 == 20
#
# 5 * 5 == 25
#
# 5 * 6 == 30
#
# 5 * 7 == 35
#
# 5 * 8 == 40
#
# 5 * 9 == 45
#
# 5 * 10 == 50
#
# 6 * 1 == 6
#
# 6 * 2 == 12
#
# 6 * 3 == 18
#
# 6 * 4 == 24
#
# 6 * 5 == 30
#
# 6 * 6 == 36
#
# 6 * 7 == 42
#
# 6 * 8 == 48
#
# 6 * 9 == 54
#
# 6 * 10 == 60
#
# 7 * 1 == 7
#
# 7 * 2 == 14
#
# 7 * 3 == 21
#
# ...
