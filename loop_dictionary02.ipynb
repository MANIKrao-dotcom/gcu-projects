# %%
students = {
    "manik": {
        "math": 85,
        "python": 92
    },
    "taufiq": {
        "math": 78,
        "python": 88
    }
}
for student, subjects in students.items():

    print("Student:", student)

    for subject, marks in subjects.items():
        print(subject, "=", marks)
# Out:
# Student: manik
# math = 85
# python = 92
# Student: taufiq
# math = 78
# python = 88
