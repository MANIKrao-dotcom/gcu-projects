# %%
a = 10
b = 20

print(a == b)   # Equal
print(a != b)   # Not Equal
print(a > b)    # Greater Than
print(a < b)    # Less Than
print(a >= b)   # Greater Than or Equal
print(a <= b)   # Less Than or Equal
# Out:
# False
# True
# False
# True
# False
# True
