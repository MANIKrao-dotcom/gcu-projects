# %%
marks = {
    "Manik": 85,
    "Taufiq": 32,
    "Abhi": 91,
    "Surya": 28,
    "Deepu": 67
}

print("Passed Students")

for name, score in marks.items():
    if score >= 35:
        print(name, "=", score)
# Out:
# Passed Students
# Manik = 85
# Abhi = 91
# Deepu = 67
