# %%
marks = {
    "Manik": 85,
    "Taufiq": 72,
    "Abhi": 91,
    "Surya": 64
}

for name, score in marks.items():
    print(f"{name} scored {score}")
# Out:
# Manik scored 85
# Taufiq scored 72
# Abhi scored 91
# Surya scored 64
