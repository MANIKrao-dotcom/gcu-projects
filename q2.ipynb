# %%
employee = {
    "Name": "Rahul",
    "Monthly Salary": 30000
}

annual_salary = employee["Monthly Salary"] * 12

print("Employee Name:", employee["Name"])
print("Annual Salary:", annual_salary)
