# %%
a = {1, 2, 3, 4}
b = {3, 4, 5, 6}

result = set()

for x in a:
    if x not in b:
        result.add(x)

for x in b:
    if x not in a:
        result.add(x)

print(result)
# Out:
# {1, 2, 5, 6}
