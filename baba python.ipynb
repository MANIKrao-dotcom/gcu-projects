# %%
print("hello world")
# Out:
# hello world

# %%
a=10
b=20
print("sum=",a+b)
# Out:
# sum= 30

# %%
a=10
b=20
print("multiplaction:",a*b)
# Out:
# multiplaction: 200

# %%
marks =67
if marks >= 90:
    print("grade a")
else:
    print("bye")
# Out:
# bye

# %%
marks =67
if marks >= 90:
    print("grade a")
elif marks >=60:
    print("grade b")
else:
    print("smooth")
# Out:
# grade b

# %%
## if else

num = int(input("enter number:"))
if num > 0:
   print("positive")
else:
   print("negative")
# Out:
# enter number: -45
# negative

# %%
## arithematic operation
a=10
b=20
print("sum=",a+b)
# Out:
# sum= 30

# %%
print("hello")
# Out:
# hello

# %%
list1 = [8,2.3,[-4,5],["apple","banana"],["manu","bhairavi"]]
print(list1)
# Out:
# [8, 2.3, [-4, 5], ['apple', 'banana'], ['manu', 'bhairavi']]

# %%
tuple1 = (("parrot","sparrow"),("lion","tiger"))
print(tuple1)
# Out:
# (('parrot', 'sparrow'), ('lion', 'tiger'))

# %%
dict1 = {"name":"manu","age":20,
         "canvote":True}
print(dict1)
# Out:
# {'name': 'manu', 'age': 20, 'canvote': True}

# %%
print(15/6)
print(5%6)
print(15//6)
print(5**3)
print(5+6)
print(15-6)
print(15*6)
# Out:
# 2.5
# 5
# 2
# 125
# 11
# 9
# 90

# %%
a = 50
b = 3
print("the value of", a ,"+",3,"is:",a+b)
print("the value of", a ,"-",3,"is:",a-b)
print("the value of", a ,"*",3,"is:",a*b)
print("the value of", a ,"/",3,"is:",a/b)
print("the value of", a ,"//",3,"is:",a//b)
print("the value of", a ,"**",3,"is:",a**b)
# Out:
# the value of 50 + 3 is: 53
# the value of 50 - 3 is: 47
# the value of 50 * 3 is: 150
# the value of 50 / 3 is: 16.666666666666668
# the value of 50 // 3 is: 16
# the value of 50 ** 3 is: 125000
