# %%
student = {"name":"manik","grade":"a","location":"india"}
print(student.get("name"))
print(student.get("address"))
student["address"] = "bidar"
print(student.get("address"))
# Out:
# manik
# None
# bidar

# %%
print(student.get("grade"))
# Out:
# a

# %%
student["name"] = "bhairava"
print(student.get("name"))
# Out:
# bhairava
