# %%
student = {"name":"manik","grade":"a","location":"india"}
student_copy = student
print(student_copy)
print(student)
##now i am modifing the  list called student
student["name"] = "rao"
print(student)
print(student_copy)
#problem if i i modified student then student _copy is also being modified at the sametime
student_copy1 = student.copy()
print(student)
print(student_copy1)
#now if i modify the one thing than the other variable also get modified?
student["name"] = "bhairava"
print(student_copy1)
print(student)
#as you can see i modified student (dictionnary),but the student_copy1(dictionary ) is not modified
#because the student_copy1 is msodified by different memory all toghether
# Out:
# {'name': 'manik', 'grade': 'a', 'location': 'india'}
# {'name': 'manik', 'grade': 'a', 'location': 'india'}
# {'name': 'rao', 'grade': 'a', 'location': 'india'}
# {'name': 'rao', 'grade': 'a', 'location': 'india'}
# {'name': 'rao', 'grade': 'a', 'location': 'india'}
# {'name': 'rao', 'grade': 'a', 'location': 'india'}
# {'name': 'rao', 'grade': 'a', 'location': 'india'}
# {'name': 'bhairava', 'grade': 'a', 'location': 'india'}
