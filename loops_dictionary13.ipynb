# %%
marks = {
    "Manik": 85,
    "Taufiq": 72,
    "Abhi": 91,
    "Surya": 68,
    "Deepu": 88
}

for name, mark in marks.items():
    if mark > 80:
        print(name, mark)
# Out:
# Manik 85
# Abhi 91
# Deepu 88
