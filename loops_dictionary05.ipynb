# %%
employees = {
    "manik": {
        "department": "IT",
        "salary": 35000,
        "experience": 2
    },

    "taufiq": {
        "department": "HR",
        "salary": 28000,
        "experience": 1
    },

    "abhi": {
        "department": "IT",
        "salary": 45000,
        "experience": 4
    }
}

for name, details in employees.items():

    print("\nEmployee:", name)

    for key, value in details.items():
        print(key, ":", value)
# Out:
# Employee: manik
# department : IT
# salary : 35000
# experience : 2
#
# Employee: taufiq
# department : HR
# salary : 28000
# experience : 1
#
# Employee: abhi
# department : IT
# salary : 45000
# experience : 4
