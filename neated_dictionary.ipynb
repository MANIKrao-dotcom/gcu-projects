# %%
student = {
    "101": {
        "name": "Manik",
        "age": 20,
        "marks": 92
    },
    "102": {
        "name": "Rahul",
        "age": 21,
        "marks": 88
    }
}

print(student)
# Out:
# {'101': {'name': 'Manik', 'age': 20, 'marks': 92}, '102': {'name': 'Rahul', 'age': 21, 'marks': 88}}

# %%
student = {
    "101": {
        "name": "Manik",
        "age": 20,
        "marks": 92
    }
}

print(student["101"]["name"])
print(student["101"]["marks"])
# Out:
# Manik
# 92
