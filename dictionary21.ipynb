# %%
students = {
    "101": {
        "Name": "Rahul",
        "Age": 20,
        "Branch": "CSE",
        "Marks": 88
    },
    "102": {
        "Name": "Priya",
        "Age": 19,
        "Branch": "ECE",
        "Marks": 91
    }
}
