# %%
students = {
    101: {
        "Name": "Ravi",
        "Marks": 89
    },
    102: {
        "Name": "Anu",
        "Marks": 92
    },
    103: {
        "Name": "Kiran",
        "Marks": 76
    }
}

roll = 102

if roll in students:
    print(students[roll])
else:
    print("Student Not Found")
# Out:
# {'Name': 'Anu', 'Marks': 92}
