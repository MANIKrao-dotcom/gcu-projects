# %%
students = {
    "student1":{"name":"manik","marks":90},
    "student2":{"name":"rao","marks":100},
    "student3":{"name":"bhairava","marks":99}
}
print(students)
# Out:
# {'student1': {'name': 'manik', 'marks': 90}, 'student2': {'name': 'rao', 'marks': 100}, 'student3': {'name': 'bhairava', 'marks': 99}}

# %%
students ["student2"]["name"] = "kaali"
print(students)
# Out:
# {'student1': {'name': 'manik', 'marks': 90}, 'student2': {'name': 'kaali', 'marks': 100}, 'student3': {'name': 'bhairava', 'marks': 99}}
