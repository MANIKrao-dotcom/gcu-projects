# %%
'''1.the set is unorderd,cant be duplicated
2.set is mutable but specific element in set is immutable bcz of its unordered nature unlike other collections in python there is no indexing attached to it so we cant directly acess any element of the set by the index'''
set1 ={1, 2, "hello", "gcu"}
print("printing all the lelements from the set given above:",set1)
# Out:
# printing all the lelements from the set given above: {1, 2, 'gcu', 'hello'}

# %% [markdown]
# OPERATORS:
# | = UNION OPERATOR:all the items that are present in both sets
# & = INTERSECTION OPERATOR:elements common in both of set
# - = DIFFERENCE OPERATOR:remove all the elements in set1 which are  present in set2

# %%
'''it dont repeat the days given in the list'''
days1 ={"mon", "tue", "wed", "sat"}
days2 ={"thr", "fri", "sat","sun","mon"}
print("day1 union days2 is:",days1|days2)
# Out:
# day1 union days2 is: {'wed', 'thr', 'sun', 'sat', 'tue', 'fri', 'mon'}
