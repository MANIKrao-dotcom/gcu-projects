# %%
student ={
    "student1" :{"name" :"manik","grade":"a","location" :"india"},
    "student2"  :{"name" : "rao","grade":"b","location":"balochistan"}
}
print(student)
# Out:
# {'student1': {'name': 'manik', 'grade': 'a', 'location': 'india'}, 'student2': {'name': 'rao', 'grade': 'b', 'location': 'balochistan'}}
