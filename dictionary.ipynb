# %%
student = {"name":"mani","age":"21"}
student.update({"class":"12"})
print(student)
print(student.items())
student["name"]="sudha"
print(student)
# Out:
# {'name': 'mani', 'age': '21', 'class': '12'}
# dict_items([('name', 'mani'), ('age', '21'), ('class', '12')])
# {'name': 'sudha', 'age': '21', 'class': '12'}

# %%
student["age"]="19"
print(student)
# Out:
# {'name': 'sudha', 'age': '19', 'class': '12', 'place': 'bangal', 'subject': 'english'}

# %%
print(student.get("name"))
print(student["name"])

print(student.get("age"))
print(student["age"])

print(student.get("class"))
print(student["class"])
# Out:
# sudha
# sudha
# 21
# 21
# 12
# 12

# %%
student["subject"]="english"
print(student)
print(student.items())
# Out:
# {'name': 'sudha', 'age': '21', 'class': '12', 'place': 'bangal', 'subject': 'english'}
# dict_items([('name', 'sudha'), ('age', '21'), ('class', '12'), ('place', 'bangal'), ('subject', 'english')])

# %%
student["subject"] = "maths"
print(student)
print(student.get("subject"))
print(student["subject"])
# Out:
# {'name': 'sudha', 'age': '21', 'class': '12', 'place': 'bangal', 'subject': 'maths'}
# maths
# maths

# %%
student.update({"place":"bidar"})
print(student)

student.update({"place":"bihar"})
print(student)

student["place"]="bangal"
print(student)

print(student.get("place"))
# Out:
# {'name': 'sudha', 'age': '21', 'class': '12', 'place': 'bidar'}
# {'name': 'sudha', 'age': '21', 'class': '12', 'place': 'bihar'}
# {'name': 'sudha', 'age': '21', 'class': '12', 'place': 'bangal'}
# bangal

# %%
print(student.items())
print(student.keys())
print(student.values())
# Out:
# dict_items([('name', 'sudha'), ('age', '21'), ('class', '12')])
# dict_keys(['name', 'age', 'class'])
# dict_values(['sudha', '21', '12'])
