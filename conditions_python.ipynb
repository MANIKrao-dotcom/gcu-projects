# %%
a = int(input ("enter a number:"))
b = int(input("enter a number:"))
if(a>b):
    print("a is lagrer:")
else:
    print("a is smaller:")
# Out:
# a is lagrer:

# %%
age = int(input("enter a number:"))
if(age >= 18):
    print("can vote")
    print("can drive")
else:
    print("cant vote")
    print("cant drive")
# Out:
# cant vote
# cant drive

# %%
light = "green"
if(light == "red"):
    print("go")
elif(light =="red"):
    print("stop")
elif(light == "yellow"):
    print("wait")
else:
    print("light is broken")
# Out:
# light is broken

# %%
#in python, strings(marks) is not compared with integer(number)to overcome this
#string should be onverted into integer so add int to the input ,marks = int(input("enter a number:"))
marks = int(input("enter a number:"))
if (marks>90):
    print("grade a")
elif(marks<90 and marks>80):
    print("gread b")
elif(marks<80 and marks>70):
    print("grade c")
elif(marks<70 and marks>60):
    print("gread d")
else:
    print("better luck next time:")
# Out:
# better luck next time:

# %%
age = int(input("enter a number:"))

if(age >=18):
    if(age>=80):
        print("cant drive")
    else:
        print("can drive")
else:
    print("cant drive")

print(type("age"))
print(type(age))
# Out:
# cant drive
# <class 'str'>
# <class 'int'>

# %%
age = 35
if(age >= 18):
    if(age >= 80):
        print("cant drive")
    else:
        print("can drive")
else:
    print("cant drive")
# Out:
# can drive

# %%
num = int(input("enter a number"))
if(num%2==0):
    if(num >= 16):
        print("number is large")
    else:
        print("divide by 2")
else:
    print("not divided by 2")
# Out:
# divide by 2

# %%
num = input("enter a number")
if (num %2==0):
    if(num>=16):
        print("number is big")
    else:
        print("divided by 2")
else:
    print("not divided by 2")
    #error bcz the integer is not equal to strinng to make it right add int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 num = input("enter a number")
# ----> 2 if (num %2==0):
#       3     if(num>=16):
#       4         print("number is big")
#
# TypeError: not all arguments converted during string formatting

# %%
num = int(input("enter a number"))
if(num%7==0):
    print("multipul of 7")
else:
    print("not multipul to 7")
# Out:
# multipul of 7

# %%
a = int(input("enter first nummber"))
b = int(input("enter second number"))
c = int(input("enter third number"))
if(a>b and a>c):
    print("firstt number is larger",a)
elif(b>=c):
    print("second number is lesser then a",b)
else:
    print("third number is the smallest",c)
# Out:
# second number is lesser then a 2
