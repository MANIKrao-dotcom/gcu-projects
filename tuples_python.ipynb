# %%
#a built in data type that let us creat immutable sequences of variable
#list = mutable
#strings and tuples = immutable
#index starts from 0
tup = (1, 3, 7, 4, 2)
print (tup[0])
print(tup[3])
tup[0] = 5#tuple object does not support item assignment
          #unlike string it cannot be changed in index
# Out:
# 1
# 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 7
#       5 print (tup[0])
#       6 print(tup[3])
# ----> 7 tup[0]=5#tuple object does not support item assignment
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup =()
print(tup)

a =(1, 4, 3, 2)
print( a[1] )
print(type(a))

a = (1)# to make it tuple we need to add coma,in perentisis
print(type (a))

a = (1,)
print(tup)
print(type(a))
# Out:
# ()
# 4
# <class 'tuple'>
# <class 'int'>
# ()
# <class 'tuple'>

# %%
#slicing is same as list
#return index of first occerence
a = (2, 3, 6, 7, 4, 9)
print (a.index(3))
# Out:
# 1

# %%
#counts total occerence
tup = (2, 4, 7, 5, 4, 2, 5, 2, 4)
print(tup.count(2))
print(tup.count(4))
print(len(tup))
# Out:
# 3
# 3
# 9

# %%
tuple = ["c", "d", "a", "a", "b", "b", "a"]
print(tuple.count("a"))


(tuple.sort())
print(tuple)
# Out:
# 3
# ['a', 'a', 'a', 'b', 'b', 'c', 'd']

# %%
#slicing in tuple
tup = (2, 6, 7, 4, 5, 9, 5)
print(tup[2:4])
print(tup[0:6])
print(tup[:6])
print(tup[2:7])
print(tup[2:len(tup)])
# Out:
# (7, 4)
# (2, 6, 7, 4, 5, 9)
# (2, 6, 7, 4, 5, 9)
# (7, 4, 5, 9, 5)
# (7, 4, 5, 9, 5)

# %%
#tuples append not possible because we cant make any changes in the main list
#unlike string or list
